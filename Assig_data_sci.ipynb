# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_excel('/content/iris.xls')

# %%
data
# Out:
#       SL   SW   PL   PW  Classification
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# data['SL'].plot(kind='hist', bins=20, title='SL')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# data['SW'].plot(kind='hist', bins=20, title='SW')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# ...

# %%
# columns in the dataset
data.columns
# Out:
# Index(['SL', 'SW', 'PL', 'PW', 'Classification'], dtype='object')

# %%
# Mean of each column of the dataset.
data[['SL', 'SW', 'PL', 'PW']].mean()
# Out:
# SL    5.843333
# SW    3.054000
# PL    3.758667
# PW    1.198667
# dtype: float64

# %%
# null values present in the dataset
data.isna().sum()
# Out:
# SL                0
# SW                0
# PL                0
# PW                0
# Classification    0
# dtype: int64

# %%
# VISAUALIZATIONS
data.plot(kind = 'line')
# Out:
# <Axes: >

# %%
data.plot(kind='box', subplots=True, layout=(2,2), sharex=False, sharey=False)
# Out:
# SL       Axes(0.125,0.53;0.352273x0.35)
# SW    Axes(0.547727,0.53;0.352273x0.35)
# PL       Axes(0.125,0.11;0.352273x0.35)
# PW    Axes(0.547727,0.11;0.352273x0.35)
# dtype: object

# %%
data.groupby('Classification').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
figsize = (12, 1.2 * len(data['Classification'].unique()))
plt.figure(figsize=figsize)
sns.violinplot(data, x='SL', y='Classification', inner='stick', palette='Dark2')
sns.despine(top=True, right=True, bottom=True, left=True)
# Out:
# <ipython-input-34-eb8acda6c4b2>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data, x='SL', y='Classification', inner='stick', palette='Dark2')

# %%
figsize = (12, 1.2 * len(data['Classification'].unique()))
plt.figure(figsize=figsize)
sns.violinplot(data, x='SW', y='Classification', inner='stick', palette='Dark2')
sns.despine(top=True, right=True, bottom=True, left=True)
# Out:
# <ipython-input-38-373877cd9fbf>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data, x='SW', y='Classification', inner='stick', palette='Dark2')

# %%
figsize = (12, 1.2 * len(data['Classification'].unique()))
plt.figure(figsize=figsize)
sns.violinplot(data, x='PL', y='Classification', inner='stick', palette='Dark2')
sns.despine(top=True, right=True, bottom=True, left=True)
# Out:
# <ipython-input-39-5395b0cc2aba>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data, x='PL', y='Classification', inner='stick', palette='Dark2')

# %%
figsize = (12, 1.2 * len(data['Classification'].unique()))
plt.figure(figsize=figsize)
sns.violinplot(data, x='PW', y='Classification', inner='stick', palette='Dark2')
sns.despine(top=True, right=True, bottom=True, left=True)
# Out:
# <ipython-input-40-efe0ec0a11f5>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data, x='PW', y='Classification', inner='stick', palette='Dark2')
